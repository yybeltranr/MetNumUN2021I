# %% [markdown]
# # Introduction to Numerical Analysis
# ### Certificado Coursera

# %% [markdown]
# ![Diploma Introduction to Numerical Analysis.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### Link del Certificado

# %% [markdown]
# https://www.coursera.org/account/accomplishments/certificate/9SSF867F9H4H
