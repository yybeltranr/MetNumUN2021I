# %% [markdown]
# # **Cognitive Class**
# ## Applied Data Science with Python

# %% [markdown]
# ### **Certificados de los cursos**

# %% [markdown]
#  1. Python 101 for Data Science
#
#   Link: https://courses.cognitiveclass.ai/certificates/6a531e84461c4e6fb8dea61aa74adca4
#
# 2. Data Analysis with Python
#
#   Link: https://courses.cognitiveclass.ai/certificates/9e7c02bb6ba848a1bdd801ff77b4727b
#
# 3. Data Visualization with Python
#
#   Link: https://courses.cognitiveclass.ai/certificates/0349b4f2e883417d8373f07de680f87a

# %% [markdown]
# ## **Imagen del posteo en LinkedIn**

# %% [markdown]
# ![cognitiveclassapplieddatadciencewithpython.JPG](data:image/jpeg;base64,...)
